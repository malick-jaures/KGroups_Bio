# %% [markdown]
# This notebook was inspired by this this [Pythonic Excursions notebook](https://aegis4048.github.io/mutiple_linear_regression_and_visualization_in_python)

# %% [markdown]
# # Packages

# %%
import pandas as pd
import numpy as np
import gc
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.svm import LinearSVR
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.metrics import r2_score, root_mean_squared_error
import sklearn

import sys
sys.path.append("../utils/")
# from util_selector import format_time
from util_preprocessing import check_or_create_directory
# from util_postprocessing import *
# from util_models import *

RANDOM_STATE = 11

sklearn.random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)

# %% [markdown]
# # Loading Data

# %%
df = pd.read_excel("./inputs/For Thesis - Chap6 - 2.xlsx", sheet_name="For Thesis - Chap6")
print(df.shape)
df
# Out:
# (33, 11)
#                                             Reference Type  Year  \
# 0                          \citet{battiti_using_1994}    J  1994
# 1                             \citet{kwak_input_2002}    J  2002
# 2                           \citet{peng_feature_2005}    J  2005
# 3                           \citet{ding_minimum_2005}    J  2005
# 4                        \citet{lin_conditional_2006}    C  2006
# 5                        \citet{mandal_improved_2013}    J  2013
# 6   \citet{yang_minimal-redundancy-maximal-relevan...    C  2013
# 7                          \citet{zhang_compact_2014}    C  2014
# 8                       \citet{bennasar_feature_2015}    J  2015
# 9                        \citet{berrendero_mrmr_2016}    J  2016
# 10               \citet{dubey_cosine-similarity_2017}    J  2017
# 11                            \citet{senawi_new_2017}    J  2017
# 12             \citet{ramirez-gallego_fast-mrmr_2017}    J  2017
# 13                           \citet{che_maximum_2017}    J  2017
# 14                       \citet{radovic_minimum_2017}    J  2017
# 15                           \citet{jo_improved_2019}    J  2019
# 16                          \citet{zhao_maximum_2019}    C  2019
# 17                        \citet{bugata_aspects_2019}    J  2019
# 18                                \citet{li_new_2020}    J  2020
# 19                         \citet{zhang_feature_2020}    J  2020
# 20                      \citet{huang_multilabel_2020}    J  2020
# 21              \citet{zhang_conditional-weight_2021}    J  2021
# 22                     \citet{bommert_benchmark_2022}    J  2022
# 23                         \citet{yuan_cscim_fs_2023}    J  2023
# 24                          \citet{wang_feature_2023}    J  2023
# 25                          \citet{yuan_feature_2024}    J  2024
# 26                    \citet{ihianle_minimising_2024}    J  2024
# 27                          \citet{yuan_feature_2025}    J  2025
# 28                                  Average (overall)    -     -
# 29                          Average (1990s and 2000s)    -     -
# 30                                    Average (2010s)    -     -
# 31                                    Average (2020s)    -     -
# 32                                               Ours    J  2026
#
#                                                 Title  \
# 0   Using Mutual Information for Selecting Feature...
# 1   Input feature selection for classification pro...
# 2   Feature selection based on mutual information ...
# 3   MINIMUM REDUNDANCY FEATURE SELECTION FROM MICR...
# 4   Conditional Infomax Learning: An Integrated Fr...
# 5   An Improved Minimum Redundancy Maximum Relevan...
# 6   Minimal-redundancy-maximal-relevance feature s...
# 7   Compact Representation for Image Classificatio...
# 8   Feature selection using Joint Mutual Informati...
# 9   The mRMR variable selection method: a comparat...
# 10  A Cosine-Similarity Mutual-Information Approac...
# 11  A new maximum relevance-minimum multicollinear...
# 12  Fast-mRMR: Fast Minimum Redundancy Maximum Rel...
# 13  Maximum relevance minimum common redundancy fe...
# 14  Minimum redundancy maximum relevance feature s...
# 15  Improved Measures of Redundancy and Relevance ...
# 16  Maximum Relevance and Minimum Redundancy Featu...
# 17  On some aspects of minimum redundancy maximum ...
# 18  A new feature selection algorithm based on rel...
# 19  Feature selection considering Uncertainty Chan...
# 20  Multilabel Feature Selection Using Relief and ...
# 21  A conditional-weight joint relevance metric fo...
# 22  Benchmark of filter methods for feature select...
# 23  CSCIM_FS: Cosine similarity coefficient and in...
# 24  Feature Selection With Maximal Relevance and M...
# 25  Feature Selection Based on Intrusive Outliers ...
# 26  Minimising redundancy, maximising relevance: H...
# 27  Feature selection method based on wavelet simi...
# 28                                                  -
# 29                                                  -
# 30                                                  -
# 31                                                  -
# 32                                                  -
#
#                                                 Venue #Datasets #Baselines  \
# 0   IEEE Transactions on Neural Networks [and Lear...         2          2
# 1   IEEE Transactions on Neural Networks [and Lear...         2          4
# 2   IEEE Transactions on Pattern Analysis and Mach...         4          1
# 3   Journal of Bioinformatics and Computational Bi...         6          2
# 4          9th European Conference on Computer Vision         3          4
# 5                                 Procedia Technology         4          2
# 6   IEEE Symposium on Computational Intelligence i...         5          1
# 7   IEEE Conference on Computer Vision and Pattern...         4          2
# 8                    Expert Systems with Applications        11          5
# 9   Journal of Statistical Computation and Simulation         -          3
# 10         Journal of Information Technology Research        18          1
# 11                                Pattern Recognition         8          2
# 12       International Journal of Intelligent Systems         5          -
# 13                               Information Sciences         4          3
# 14                                 BMC Bioinformatics         3          4
# 15                                          Computers        10          4
# 16  IEEE International Conference on Data Science ...         3          5
# 17                 Science China Information Sciences         8          -
# 18                  Computers in Biology and Medicine        15         11
# 19                             Applied Soft Computing        14          7
# 20                                        IEEE Access         9          7
# 21  Engineering Applications of Artificial Intelli...        19          7
# 22                        Briefings in Bioinformatics        11          -
# 23                                     Neurocomputing        10          9
# 24                   IEEE Transactions on Cybernetics        12          7
# 25              IEEE Transactions on Image Processing         8         10
# 26                   Expert Systems with Applications         3          4
# 27                               Information Sciences         9          7
# 28                                                  -  7.777778       4.56
# 29                                                  -       3.4        2.6
# 30                                                  -  6.916667   2.909091
# 31                                                  -        11   7.666667
# 32                                                  -       14*         4*
#
#    #NewMethods    WinRate SuccessRate  \
# 0            1        100           -
# 1            2        100          50
# 2            1        100           -
# 3            4        100           -
# 4            2        100           -
# 5            1        100           -
# 6            2         80         100
# 7            1         50           -
# 8            2       63.6           -
# 9            2        100         100
# 10           1       72.2           -
# 11           1         50           -
# 12           -          -           -
# 13           1         50           -
# 14           2        100           -
# 15           1        100           -
# 16           3       66.7        66.7
# 17           -          -           -
# 18           1       33.3           -
# 19           1       71.4           -
# 20           1       66.7           -
# 21           1       63.2        57.9
# 22           -          -           -
# 23           1         70           -
# 24           1       83.3           -
# 25           2       62.3           -
# 26           4        100        66.7
# 27           1       66.7           -
# 28         1.6     77.976       73.55
# 29           2        100          50
# 30    1.545455  75.681818        88.9
# 31    1.444444  68.544444        62.3
# 32          2*      78.6*       92.9*
#
#                                                 Notes
# 0   - 1st mRMR (MIFS) - 1 hyperparameter beta - 3 ...
# 1   - Not Outperform all competitions? - MIFS incl...
# 2   - Include NCI[9] dataset - Hybrid with Forward...
# 3   - Include NCI[9] - Introduced mRMR_MID, mRMR_M...
# 4                                                 NaN
# 5   - Both formulations of mRMR with MI as baselin...
# 6   - 3 rel. est. with k in {20,40,60, 80, 100, Al...
# 7   - Introduced 2 baselines but used one of them ...
# 8   - 2 FS methods - Information theory-based base...
# 9   - Study the  mRMR_D for different relevance es...
# 10                                - KBest with IG/MI
# 11  - 1 variant formulation of mRMR - mRMR and MIF...
# 12  - Include NCI[9] dataset - 5 datasets + 3 addi...
# 13  - Include running time - k in {2,3,...,60} - 2...
# 14  - k in {1,10,20,30,40,50} - Time series analys...
# 15  - 4 classifiers (KNN, LinearSVM, DT, RF) - k i...
# 16  - 3 new extensions of mRMR (FRQ, RFCQ, RFRQ) c...
# 17               - Ablation study of mRMR - Benchmark
# 18  - Include running time in Big-O notation - 1 v...
# 19  - Include running time - mRMR_MID - MI based b...
# 20  - 13 datasets but 9 reported (on average). - M...
# 21       - mRMR_MID - Only MI and SU-based baselines.
# 22  - 1 variant formulation of mRMR - zero because...
# 23  - 12 datasets but 10 reported - Both formulati...
# 24  - Information theory-based baselines - extensi...
# 25  - no variants formulation of mRMR but its exte...
# 26  - many rel. est. with k in {10,15,20, All feat...
# 27  - 13 datasets but 9 reported - MI and SU (symm...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN

# %%
df = df.loc[:27, ["#Datasets", "#Baselines", "#NewMethods", "WinRate"]]
gc.collect()
print(df.shape)
df
# Out:
# (28, 4)
#    #Datasets #Baselines #NewMethods WinRate
# 0          2          2           1     100
# 1          2          4           2     100
# 2          4          1           1     100
# 3          6          2           4     100
# 4          3          4           2     100
# 5          4          2           1     100
# 6          5          1           2      80
# 7          4          2           1      50
# 8         11          5           2    63.6
# 9          -          3           2     100
# 10        18          1           1    72.2
# 11         8          2           1      50
# 12         5          -           -       -
# 13         4          3           1      50
# 14         3          4           2     100
# 15        10          4           1     100
# 16         3          5           3    66.7
# 17         8          -           -       -
# 18        15         11           1    33.3
# 19        14          7           1    71.4
# 20         9          7           1    66.7
# 21        19          7           1    63.2
# 22        11          -           -       -
# 23        10          9           1      70
# 24        12          7           1    83.3
# 25         8         10           2    62.3
# 26         3          4           4     100
# 27         9          7           1    66.7

# %%
df = df.replace("-", np.nan)
df.isna().sum()
# Out:
# /var/folders/1m/rg_439m51rq_rwrbgdqbblxm0000gn/T/ipykernel_11737/3928926352.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace("-", np.nan)
# #Datasets      1
# #Baselines     3
# #NewMethods    3
# WinRate        3
# dtype: int64

# %% [markdown]
# # Preprocessing

# %%
# # Dropping missing values 
# df = df.dropna(
#     subset=[
#         "WinRate",
#         "#Datasets",
#     ]
# ).reset_index(drop=True)
# print(df.shape)
# df

# %%
# pd.DataFrame.fillna?

# %%
# Mean imputer
for col in df.columns:
    df[col] = df[col].fillna(value=df[col].mean())
    # print(df[col].mean())

# %% [markdown]
# # Splitting data into train and test

# %%
X = df.drop("WinRate", axis=1)
y = df["WinRate"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, shuffle=True,
    random_state=RANDOM_STATE
)

print(X_train.shape, X_test.shape)
# Out:
# (18, 3) (10, 3)

# %% [markdown]
# # Training a linear model
#
# ## Using train and test data

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_p = lr.predict(X_train)
y_test_p = lr.predict(X_test)

r2_score(y_train, y_train_p) , r2_score(y_test, y_test_p)
# Out:
# (0.33806972266904045, 0.07284695864786606)

# %% [markdown]
# ## Using the whole data

# %%
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
y_p = lr.predict(X)

rmse = root_mean_squared_error(y, y_p) 
r2 = lr.score(X,y)

rmse, r2
# Out:
# (15.75352720833294, 0.3330795472882414)

# %% [markdown]
# ## PCA components

# %%
pca = PCA(n_components=0.99)
pca.fit(X)
pca.explained_variance_ratio_
# Out:
# array([0.80367769, 0.17600196, 0.02032035])

# %%
pca = PCA(n_components=1)
pca.fit(X)
pca.explained_variance_ratio_
# Out:
# array([0.80367769])

# %%
X_pca = pca.transform(X)

# %% [markdown]
# ## Using the PCA components

# %%
lr = LinearRegression()
lr.fit(X_pca, y)
# Out:
# LinearRegression()

# %%
y_pca_p = lr.predict(X_pca)

rmse_pca = root_mean_squared_error(y, y_pca_p) 
r2_pca2 = r2_score(y, y_pca_p) 

r2_pca =lr.score(X_pca,y)

rmse_pca, r2_pca , r2_pca2
# Out:
# (16.790484480692236, 0.24239143321346324, 0.24239143321346324)

# %% [markdown]
# # Visualization

# %%
imgs_saving_dir = "./outputs/extracted_results/imgs"
check_or_create_directory(imgs_saving_dir)
# Out:
# Directory already exists: outputs/extracted_results/imgs

# %%
plt.style.use('default')
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(X_pca, y_pca_p, color='k', label='Regression model')
ax.scatter(X_pca, y, edgecolor='k', facecolor='grey', alpha=0.7, label='Sample data')
ax.set_ylabel('Win Rate', fontsize=14)
ax.set_xlabel('1 PCA component with {:.2%} of the Explained Variance of the Sample data'.format(pca.explained_variance_ratio_[0]), fontsize=12)
ax.legend(facecolor='white', fontsize=11)
ax.set_title('$R^2= {:.2f}, RMSE={:.1f}$'.format(r2, rmse) , fontsize=16)

fig.tight_layout()
fig.savefig(imgs_saving_dir+"/correlation between Win Rate and Sample data.png", dpi=600, bbox_inches='tight')
