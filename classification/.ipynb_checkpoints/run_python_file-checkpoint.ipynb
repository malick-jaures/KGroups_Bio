# %%
## Python 3.8 at least
# !python3 --version
# Out:
# Python 3.12.7

# %%
# !python3 default_data_with_all_features.py
# Out:
# 100%|████████████████████████████████████████| 27/27 [1:07:48<00:00, 150.70s/it]

# %%
# !python3 run_experiments_on_all_datasets.py
# Out:
#   0%|                                                     | 0/3 [00:00<?, ?it/s]
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# 1/1 tie breaker(s) have/has been applied!
#
# Applying the tie breaker(s) ...
# ...
